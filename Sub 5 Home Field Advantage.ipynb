# %%
import pandas as pd

#import attendance data

fans = pd.read_csv("C:\\Users\\dante\\Downloads\\attendance.csv")
fans.drop(["att avg5", "att avg10", "att avg15", "att 2021", "att 2020"], axis=1, inplace=True)

#import standings
twenty08 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2008 standings.csv")

#calculate home win percentage
twenty08[['home_wins', 'home_losses']] = twenty08['Home'].str.split('-', expand=True)
twenty08['home_wins'] = pd.to_numeric(twenty08['home_wins'])
twenty08['home_losses'] = pd.to_numeric(twenty08['home_losses'])
twenty08['home_perc'] = twenty08['home_wins'] / (twenty08['home_wins'] + twenty08['home_losses'])

#calculate road win percentage
twenty08[['road_wins', 'road_losses']] = twenty08['Road'].str.split('-', expand=True)
twenty08['road_wins'] = pd.to_numeric(twenty08['road_wins'])
twenty08['road_losses'] = pd.to_numeric(twenty08['road_losses'])
twenty08['road_perc'] = twenty08['road_wins'] / (twenty08['road_wins'] + twenty08['road_losses'])

#home minus road equals home field advantage
twenty08['hf_adv'] = twenty08['home_perc'] - twenty08['road_perc']

#rename teams to be consistent with attendance dataset
twenty08['Tm'] = twenty08['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty08['Tm'] = twenty08['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

#add attendance
fans08 = fans[['franchise', 'att 2008']]
twenty08 = fans08.merge(twenty08, left_on='franchise', right_on='Tm')

#remove variables I will not be working with
twenty08 = twenty08[['att 2008', 'Tm', 'W-L%', 'hf_adv']]

#add year to team name and remove from other variables to help differentiate teams
twenty08.rename(columns={'att 2008': 'att'}, inplace=True)
twenty08['Tm'] = '2008 ' + twenty08['Tm']

#reorder columns
cols = twenty08.columns.tolist()
cols.remove('att')
cols.append('att')  
twenty08 = twenty08[cols] 

print(twenty08.head())
# Out:
#                           Tm   W-L%    hf_adv        att
# 0  2008 Arizona Diamondbacks  0.506  0.172840  2,509,924
# 1        2008 Atlanta Braves  0.444  0.172840  2,532,834
# 2     2008 Baltimore Orioles  0.422  0.079784  1,950,075
# 3        2008 Boston Red Sox  0.586  0.209877  3,048,250
# 4          2008 Chicago Cubs  0.602  0.154012  3,300,200

# %%
#repeating other years with some help from gpt to rewrite the same code quickly

twenty09 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2009 standings.csv")

twenty09[['home_wins', 'home_losses']] = twenty09['Home'].str.split('-', expand=True)
twenty09['home_wins'] = pd.to_numeric(twenty09['home_wins'])
twenty09['home_losses'] = pd.to_numeric(twenty09['home_losses'])
twenty09['home_perc'] = twenty09['home_wins'] / (twenty09['home_wins'] + twenty09['home_losses'])

# Calculate road win percentage
twenty09[['road_wins', 'road_losses']] = twenty09['Road'].str.split('-', expand=True)
twenty09['road_wins'] = pd.to_numeric(twenty09['road_wins'])
twenty09['road_losses'] = pd.to_numeric(twenty09['road_losses'])
twenty09['road_perc'] = twenty09['road_wins'] / (twenty09['road_wins'] + twenty09['road_losses'])

# Home minus road equals home field advantage
twenty09['hf_adv'] = twenty09['home_perc'] - twenty09['road_perc']

# Rename teams to be consistent with attendance dataset
twenty09['Tm'] = twenty09['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty09['Tm'] = twenty09['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans09 = fans[['franchise', 'att 2009']]
twenty09 = fans09.merge(twenty09, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty09 = twenty09[['att 2009', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty09.rename(columns={'att 2009': 'att'}, inplace=True)
twenty09['Tm'] = '2009 ' + twenty09['Tm']

# Reorder columns
cols = twenty09.columns.tolist()
cols.remove('att')
cols.append('att')
twenty09 = twenty09[cols]

print(twenty09.head())

twenty10 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2010 standings.csv")

twenty10[['home_wins', 'home_losses']] = twenty10['Home'].str.split('-', expand=True)
twenty10['home_wins'] = pd.to_numeric(twenty10['home_wins'])
twenty10['home_losses'] = pd.to_numeric(twenty10['home_losses'])
twenty10['home_perc'] = twenty10['home_wins'] / (twenty10['home_wins'] + twenty10['home_losses'])

# Calculate road win percentage
twenty10[['road_wins', 'road_losses']] = twenty10['Road'].str.split('-', expand=True)
twenty10['road_wins'] = pd.to_numeric(twenty10['road_wins'])
twenty10['road_losses'] = pd.to_numeric(twenty10['road_losses'])
twenty10['road_perc'] = twenty10['road_wins'] / (twenty10['road_wins'] + twenty10['road_losses'])

# Home minus road equals home field advantage
twenty10['hf_adv'] = twenty10['home_perc'] - twenty10['road_perc']

# Rename teams to be consistent with attendance dataset
twenty10['Tm'] = twenty10['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty10['Tm'] = twenty10['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans10 = fans[['franchise', 'att 2010']]
twenty10 = fans10.merge(twenty10, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty10 = twenty10[['att 2010', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty10.rename(columns={'att 2010': 'att'}, inplace=True)
twenty10['Tm'] = '2010 ' + twenty10['Tm']

# Reorder columns
cols = twenty10.columns.tolist()
cols.remove('att')
cols.append('att')
twenty10 = twenty10[cols]

print(twenty10.head())

twenty11 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2011 standings.csv")

twenty11[['home_wins', 'home_losses']] = twenty11['Home'].str.split('-', expand=True)
twenty11['home_wins'] = pd.to_numeric(twenty11['home_wins'])
twenty11['home_losses'] = pd.to_numeric(twenty11['home_losses'])
twenty11['home_perc'] = twenty11['home_wins'] / (twenty11['home_wins'] + twenty11['home_losses'])

# Calculate road win percentage
twenty11[['road_wins', 'road_losses']] = twenty11['Road'].str.split('-', expand=True)
twenty11['road_wins'] = pd.to_numeric(twenty11['road_wins'])
twenty11['road_losses'] = pd.to_numeric(twenty11['road_losses'])
twenty11['road_perc'] = twenty11['road_wins'] / (twenty11['road_wins'] + twenty11['road_losses'])

# Home minus road equals home field advantage
twenty11['hf_adv'] = twenty11['home_perc'] - twenty11['road_perc']

# Rename teams to be consistent with attendance dataset
twenty11['Tm'] = twenty11['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty11['Tm'] = twenty11['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans11 = fans[['franchise', 'att 2011']]
twenty11 = fans11.merge(twenty11, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty11 = twenty11[['att 2011', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty11.rename(columns={'att 2011': 'att'}, inplace=True)
twenty11['Tm'] = '2011 ' + twenty11['Tm']

# Reorder columns
cols = twenty11.columns.tolist()
cols.remove('att')
cols.append('att')
twenty11 = twenty11[cols]

print(twenty11.head())

twenty12 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2012 standings.csv")

twenty12[['home_wins', 'home_losses']] = twenty12['Home'].str.split('-', expand=True)
twenty12['home_wins'] = pd.to_numeric(twenty12['home_wins'])
twenty12['home_losses'] = pd.to_numeric(twenty12['home_losses'])
twenty12['home_perc'] = twenty12['home_wins'] / (twenty12['home_wins'] + twenty12['home_losses'])

# Calculate road win percentage
twenty12[['road_wins', 'road_losses']] = twenty12['Road'].str.split('-', expand=True)
twenty12['road_wins'] = pd.to_numeric(twenty12['road_wins'])
twenty12['road_losses'] = pd.to_numeric(twenty12['road_losses'])
twenty12['road_perc'] = twenty12['road_wins'] / (twenty12['road_wins'] + twenty12['road_losses'])

# Home minus road equals home field advantage
twenty12['hf_adv'] = twenty12['home_perc'] - twenty12['road_perc']

# Rename teams to be consistent with attendance dataset
twenty12['Tm'] = twenty12['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty12['Tm'] = twenty12['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans12 = fans[['franchise', 'att 2012']]
twenty12 = fans12.merge(twenty12, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty12 = twenty12[['att 2012', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty12.rename(columns={'att 2012': 'att'}, inplace=True)
twenty12['Tm'] = '2012 ' + twenty12['Tm']

# Reorder columns
cols = twenty12.columns.tolist()
cols.remove('att')
cols.append('att')
twenty12 = twenty12[cols]

print(twenty12.head())

twenty13 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2013 standings.csv")
twenty13[['home_wins', 'home_losses']] = twenty13['Home'].str.split('-', expand=True)
twenty13['home_wins'] = pd.to_numeric(twenty13['home_wins'])
twenty13['home_losses'] = pd.to_numeric(twenty13['home_losses'])
twenty13['home_perc'] = twenty13['home_wins'] / (twenty13['home_wins'] + twenty13['home_losses'])

# Calculate road win percentage
twenty13[['road_wins', 'road_losses']] = twenty13['Road'].str.split('-', expand=True)
twenty13['road_wins'] = pd.to_numeric(twenty13['road_wins'])
twenty13['road_losses'] = pd.to_numeric(twenty13['road_losses'])
twenty13['road_perc'] = twenty13['road_wins'] / (twenty13['road_wins'] + twenty13['road_losses'])

# Home minus road equals home field advantage
twenty13['hf_adv'] = twenty13['home_perc'] - twenty13['road_perc']

# Rename teams to be consistent with attendance dataset
twenty13['Tm'] = twenty13['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty13['Tm'] = twenty13['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans13 = fans[['franchise', 'att 2013']]
twenty13 = fans13.merge(twenty13, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty13 = twenty13[['att 2013', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty13.rename(columns={'att 2013': 'att'}, inplace=True)
twenty13['Tm'] = '2013 ' + twenty13['Tm']

# Reorder columns
cols = twenty13.columns.tolist()
cols.remove('att')
cols.append('att')
twenty13 = twenty13[cols]

print(twenty13.head())

twenty14 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2014 standings.csv")
twenty14[['home_wins', 'home_losses']] = twenty14['Home'].str.split('-', expand=True)
twenty14['home_wins'] = pd.to_numeric(twenty14['home_wins'])
twenty14['home_losses'] = pd.to_numeric(twenty14['home_losses'])
twenty14['home_perc'] = twenty14['home_wins'] / (twenty14['home_wins'] + twenty14['home_losses'])

# Calculate road win percentage
twenty14[['road_wins', 'road_losses']] = twenty14['Road'].str.split('-', expand=True)
twenty14['road_wins'] = pd.to_numeric(twenty14['road_wins'])
twenty14['road_losses'] = pd.to_numeric(twenty14['road_losses'])
twenty14['road_perc'] = twenty14['road_wins'] / (twenty14['road_wins'] + twenty14['road_losses'])

# Home minus road equals home field advantage
twenty14['hf_adv'] = twenty14['home_perc'] - twenty14['road_perc']

# Rename teams to be consistent with attendance dataset
twenty14['Tm'] = twenty14['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty14['Tm'] = twenty14['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans14 = fans[['franchise', 'att 2014']]
twenty14 = fans14.merge(twenty14, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty14 = twenty14[['att 2014', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty14.rename(columns={'att 2014': 'att'}, inplace=True)
twenty14['Tm'] = '2014 ' + twenty14['Tm']

# Reorder columns
cols = twenty14.columns.tolist()
cols.remove('att')
cols.append('att')
twenty14 = twenty14[cols]

print(twenty14.head())

twenty15 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2015 standings.csv")
twenty15[['home_wins', 'home_losses']] = twenty15['Home'].str.split('-', expand=True)
twenty15['home_wins'] = pd.to_numeric(twenty15['home_wins'])
twenty15['home_losses'] = pd.to_numeric(twenty15['home_losses'])
twenty15['home_perc'] = twenty15['home_wins'] / (twenty15['home_wins'] + twenty15['home_losses'])

# Calculate road win percentage
twenty15[['road_wins', 'road_losses']] = twenty15['Road'].str.split('-', expand=True)
twenty15['road_wins'] = pd.to_numeric(twenty15['road_wins'])
twenty15['road_losses'] = pd.to_numeric(twenty15['road_losses'])
twenty15['road_perc'] = twenty15['road_wins'] / (twenty15['road_wins'] + twenty15['road_losses'])

# Home minus road equals home field advantage
twenty15['hf_adv'] = twenty15['home_perc'] - twenty15['road_perc']

# Rename teams to be consistent with attendance dataset
twenty15['Tm'] = twenty15['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty15['Tm'] = twenty15['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans15 = fans[['franchise', 'att 2015']]
twenty15 = fans15.merge(twenty15, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty15 = twenty15[['att 2015', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty15.rename(columns={'att 2015': 'att'}, inplace=True)
twenty15['Tm'] = '2015 ' + twenty15['Tm']

# Reorder columns
cols = twenty15.columns.tolist()
cols.remove('att')
cols.append('att')
twenty15 = twenty15[cols]

print(twenty15.head())

twenty16 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2016 standings.csv")

twenty16[['home_wins', 'home_losses']] = twenty16['Home'].str.split('-', expand=True)
twenty16['home_wins'] = pd.to_numeric(twenty16['home_wins'])
twenty16['home_losses'] = pd.to_numeric(twenty16['home_losses'])
twenty16['home_perc'] = twenty16['home_wins'] / (twenty16['home_wins'] + twenty16['home_losses'])

# Calculate road win percentage
twenty16[['road_wins', 'road_losses']] = twenty16['Road'].str.split('-', expand=True)
twenty16['road_wins'] = pd.to_numeric(twenty16['road_wins'])
twenty16['road_losses'] = pd.to_numeric(twenty16['road_losses'])
twenty16['road_perc'] = twenty16['road_wins'] / (twenty16['road_wins'] + twenty16['road_losses'])

# Home minus road equals home field advantage
twenty16['hf_adv'] = twenty16['home_perc'] - twenty16['road_perc']

# Rename teams to be consistent with attendance dataset
twenty16['Tm'] = twenty16['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty16['Tm'] = twenty16['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans16 = fans[['franchise', 'att 2016']]
twenty16 = fans16.merge(twenty16, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty16 = twenty16[['att 2016', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty16.rename(columns={'att 2016': 'att'}, inplace=True)
twenty16['Tm'] = '2016 ' + twenty16['Tm']

# Reorder columns
cols = twenty16.columns.tolist()
cols.remove('att')
cols.append('att')
twenty16 = twenty16[cols]

print(twenty16.head())

# Repeat the same steps for the years 2017, 2018, and 2019

twenty17 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2017 standings.csv")

twenty17[['home_wins', 'home_losses']] = twenty17['Home'].str.split('-', expand=True)
twenty17['home_wins'] = pd.to_numeric(twenty17['home_wins'])
twenty17['home_losses'] = pd.to_numeric(twenty17['home_losses'])
twenty17['home_perc'] = twenty17['home_wins'] / (twenty17['home_wins'] + twenty17['home_losses'])

# Calculate road win percentage
twenty17[['road_wins', 'road_losses']] = twenty17['Road'].str.split('-', expand=True)
twenty17['road_wins'] = pd.to_numeric(twenty17['road_wins'])
twenty17['road_losses'] = pd.to_numeric(twenty17['road_losses'])
twenty17['road_perc'] = twenty17['road_wins'] / (twenty17['road_wins'] + twenty17['road_losses'])

# Home minus road equals home field advantage
twenty17['hf_adv'] = twenty17['home_perc'] - twenty17['road_perc']

# Rename teams to be consistent with attendance dataset
twenty17['Tm'] = twenty17['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty17['Tm'] = twenty17['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans17 = fans[['franchise', 'att 2017']]
twenty17 = fans17.merge(twenty17, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty17 = twenty17[['att 2017', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty17.rename(columns={'att 2017': 'att'}, inplace=True)
twenty17['Tm'] = '2017 ' + twenty17['Tm']

# Reorder columns
cols = twenty17.columns.tolist()
cols.remove('att')
cols.append('att')
twenty17 = twenty17[cols]

print(twenty17.head())

# Repeat the same steps for the years 2018 and 2019

twenty18 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2018 standings.csv")

twenty18[['home_wins', 'home_losses']] = twenty18['Home'].str.split('-', expand=True)
twenty18['home_wins'] = pd.to_numeric(twenty18['home_wins'])
twenty18['home_losses'] = pd.to_numeric(twenty18['home_losses'])
twenty18['home_perc'] = twenty18['home_wins'] / (twenty18['home_wins'] + twenty18['home_losses'])

# Calculate road win percentage
twenty18[['road_wins', 'road_losses']] = twenty18['Road'].str.split('-', expand=True)
twenty18['road_wins'] = pd.to_numeric(twenty18['road_wins'])
twenty18['road_losses'] = pd.to_numeric(twenty18['road_losses'])
twenty18['road_perc'] = twenty18['road_wins'] / (twenty18['road_wins'] + twenty18['road_losses'])

# Home minus road equals home field advantage
twenty18['hf_adv'] = twenty18['home_perc'] - twenty18['road_perc']

# Rename teams to be consistent with attendance dataset
twenty18['Tm'] = twenty18['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty18['Tm'] = twenty18['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans18 = fans[['franchise', 'att 2018']]
twenty18 = fans18.merge(twenty18, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty18 = twenty18[['att 2018', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty18.rename(columns={'att 2018': 'att'}, inplace=True)
twenty18['Tm'] = '2018 ' + twenty18['Tm']

# Reorder columns
cols = twenty18.columns.tolist()
cols.remove('att')
cols.append('att')
twenty18 = twenty18[cols]

print(twenty18.head())

twenty19 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2019 standings.csv")

twenty19[['home_wins', 'home_losses']] = twenty19['Home'].str.split('-', expand=True)
twenty19['home_wins'] = pd.to_numeric(twenty19['home_wins'])
twenty19['home_losses'] = pd.to_numeric(twenty19['home_losses'])
twenty19['home_perc'] = twenty19['home_wins'] / (twenty19['home_wins'] + twenty19['home_losses'])

# Calculate road win percentage
twenty19[['road_wins', 'road_losses']] = twenty19['Road'].str.split('-', expand=True)
twenty19['road_wins'] = pd.to_numeric(twenty19['road_wins'])
twenty19['road_losses'] = pd.to_numeric(twenty19['road_losses'])
twenty19['road_perc'] = twenty19['road_wins'] / (twenty19['road_wins'] + twenty19['road_losses'])

# Home minus road equals home field advantage
twenty19['hf_adv'] = twenty19['home_perc'] - twenty19['road_perc']

# Rename teams to be consistent with attendance dataset
twenty19['Tm'] = twenty19['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty19['Tm'] = twenty19['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans19 = fans[['franchise', 'att 2019']]
twenty19 = fans19.merge(twenty19, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty19 = twenty19[['att 2019', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty19.rename(columns={'att 2019': 'att'}, inplace=True)
twenty19['Tm'] = '2019 ' + twenty19['Tm']

# Reorder columns
cols = twenty19.columns.tolist()
cols.remove('att')
cols.append('att')
twenty19 = twenty19[cols]

print(twenty19.head())


twenty22 = pd.read_csv("C:\\Users\\dante\\Documents\\Downloads\\2022 standings.csv")

twenty22[['home_wins', 'home_losses']] = twenty22['Home'].str.split('-', expand=True)
twenty22['home_wins'] = pd.to_numeric(twenty22['home_wins'])
twenty22['home_losses'] = pd.to_numeric(twenty22['home_losses'])
twenty22['home_perc'] = twenty22['home_wins'] / (twenty22['home_wins'] + twenty22['home_losses'])

# Calculate road win percentage
twenty22[['road_wins', 'road_losses']] = twenty22['Road'].str.split('-', expand=True)
twenty22['road_wins'] = pd.to_numeric(twenty22['road_wins'])
twenty22['road_losses'] = pd.to_numeric(twenty22['road_losses'])
twenty22['road_perc'] = twenty22['road_wins'] / (twenty22['road_wins'] + twenty22['road_losses'])

# Home minus road equals home field advantage
twenty22['hf_adv'] = twenty22['home_perc'] - twenty22['road_perc']

# Rename teams to be consistent with attendance dataset
twenty22['Tm'] = twenty22['Tm'].replace('Cleveland Indians', 'Cleveland Guardians')
twenty22['Tm'] = twenty22['Tm'].replace('Los Angeles Angels of Anaheim', 'Los Angeles Angels')

# Add attendance
fans22 = fans[['franchise', 'att 2022']]
twenty22 = fans22.merge(twenty22, left_on='franchise', right_on='Tm')

# Remove variables I will not be working with
twenty22 = twenty22[['att 2022', 'Tm', 'W-L%', 'hf_adv']]

# Add year to team name and remove from other variables to help differentiate teams
twenty22.rename(columns={'att 2022': 'att'}, inplace=True)
twenty22['Tm'] = '2022 ' + twenty22['Tm']

# Reorder columns
cols = twenty22.columns.tolist()
cols.remove('att')
cols.append('att')
twenty22 = twenty22[cols]

print(twenty22.head())
# Out:
#                           Tm   W-L%    hf_adv        att
# 0  2009 Arizona Diamondbacks  0.432  0.024691  2,129,183
# 1        2009 Atlanta Braves  0.531 -0.074074  2,373,631
# 2     2009 Baltimore Orioles  0.395  0.172840  1,907,163
# 3        2009 Boston Red Sox  0.586  0.209877  3,062,699
# 4          2009 Chicago Cubs  0.516  0.118210  3,168,859
#                           Tm   W-L%    hf_adv        att
# 0  2010 Arizona Diamondbacks  0.401  0.185185  2,056,519
# 1        2010 Atlanta Braves  0.562  0.259259  2,510,119
# 2     2010 Baltimore Orioles  0.407  0.098765  1,733,018
# 3        2010 Boston Red Sox  0.549  0.037037  3,046,445
# 4          2010 Chicago Cubs  0.463 -0.061728  3,062,973
#                           Tm   W-L%    hf_adv        att
# 0  2011 Arizona Diamondbacks  0.580  0.098765  2,105,432
# 1        2011 Atlanta Braves  0.549  0.061728  2,372,940
# 2     2011 Baltimore Orioles  0.426  0.111111  1,755,461
# ...

# %%
# Concatenating all of the years
dfs = [twenty08, twenty09, twenty10, twenty11, twenty12, twenty13, twenty14, twenty15, twenty16, twenty17, twenty18, twenty19, twenty22]
combined_df = pd.concat(dfs)
combined_df.reset_index(drop=True, inplace=True)

# Forgot to remove "Average" from the standings earlier, so let's do it now
combined_df = combined_df[~combined_df['Tm'].str.contains('Average')]
combined_df.reset_index(drop=True, inplace=True)

# need to remove commas from att to make it a number
combined_df['att'] = combined_df['att'].str.replace(',', '')
combined_df['att'] = pd.to_numeric(combined_df['att'], errors='coerce')

print(combined_df)
# Out:
#                             Tm   W-L%    hf_adv      att
# 0    2008 Arizona Diamondbacks  0.506  0.172840  2509924
# 1          2008 Atlanta Braves  0.444  0.172840  2532834
# 2       2008 Baltimore Orioles  0.422  0.079784  1950075
# 3          2008 Boston Red Sox  0.586  0.209877  3048250
# 4            2008 Chicago Cubs  0.602  0.154012  3300200
# ..                         ...    ...       ...      ...
# 381   2022 St. Louis Cardinals  0.574  0.160494  3320551
# 382        2022 Tampa Bay Rays  0.531  0.197531  1128127
# 383         2022 Texas Rangers  0.420  0.000000  2011381
# 384     2022 Toronto Blue Jays  0.568  0.024691  2653830
# 385  2022 Washington Nationals  0.340 -0.037037  2026401
#
# [386 rows x 4 columns]

# %%
#Correlation matrix

columns_for_correlation = ['hf_adv','att', 'W-L%']
correlation_matrix = combined_df[columns_for_correlation].corr()

print("Correlation Matrix:")
print(correlation_matrix)
